# %%
import  pandas as pd

# %%
df=pd.read_csv("restaurants.csv")
df.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 1           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 2           5  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 3           8  k0hlBqXX-Bt0vf1op7Jr1w     Tsevi's Pub And Grill
# 4           9  bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
#
#                address          city state postal_code   latitude  longitude  \
# 0          935 Race St  Philadelphia    PA       19107  39.955505 -75.155564
# 1        101 Walnut St    Green Lane    PA       18054  40.338183 -75.471659
# 2        615 S Main St  Ashland City    TN       37015  36.269593 -87.058943
# 3    8025 Mackenzie Rd        Affton    MO       63123  38.565165 -90.321087
# 4  2312 Dickerson Pike     Nashville    TN       37207  36.208102 -86.768170
#
#    stars  review_count  is_open  \
# 0    4.0            80        1
# 1    4.5            13        1
# ...

# %%
df=pd.read_csv("sampled_yelp_reviews.csv")
df.head()
# Out:
#                 review_id             business_id  stars                 date  \
# 0  KU_O5udG6zpxOg-VcAEodg  XQfwVwDr-v0ZS3_CbbE5Xw    3.0  2018-07-07 22:09:11
# 1  BiTunyQ73aT9WBnpR9DZGw  7ATYjTIgM3jUlt4UM3IypQ    5.0  2012-01-03 15:28:18
# 2  saUsX_uimxRlCVr67Z4Jig  YjUWPpI6HXG530lwP-fb2A    3.0  2014-02-05 20:30:30
# 3  AqPFMleE6RsU23_auESxiA  kxX2SOes4o-D3ZQBkiMRfA    5.0  2015-01-04 00:01:03
# 4  Sx8TMOWLNuJBWer-0pcmoA  e4Vwtrqf-wpJfwesgvdgxQ    4.0  2017-01-14 20:54:15
#
#                                           text_clean
# 0  If you decide to eat here, just be aware it is...
# 1  I've taken a lot of spin classes over the year...
# 2  Family diner. Had the buffet. Eclectic assortm...
# 3  Wow!  Yummy, different,  delicious.   Our favo...
# 4  Cute interior and owner (?) gave us tour of up...

# %%
from geopy.geocoders import Nominatim
import pandas as pd

geolocator = Nominatim(user_agent="restaurant_locator")

def get_coords(row):
    # Creating a query string
    query = f"{row['name']}, {row['city']}, {row['state']}"
    location = geolocator.geocode(query)
    return (location.latitude, location.longitude) if location else (None, None)

# Apply to your dataframe
# restaurants_df[['lat', 'lon']] = restaurants_df.apply(get_coords, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from geopy.geocoders import Nominatim
#       2 import pandas as pd
#       3
#       4 geolocator = Nominatim(user_agent="restaurant_locator")
#
# ModuleNotFoundError: No module named 'geopy'

# %%
import pandas as pd

df = pd.read_csv("Dataset.csv")

# %% [markdown]
# df.describe()

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df=pd.read_csv('E:\\Marketing\\sales_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df=pd.read_csv('E:\\Marketing\\sales_data.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\gasit\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
